# %% [markdown]
# # Data Analysis of Movies Ratings, Votes and Scores¶
# import Required Modules

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import pyplot
# %matplotlib inline

# %% [markdown]
# # Read Data

# %%
data = pd.read_csv('C:/Users/Sabrina1/Desktop/ACT RECORDINGS/archive/movies.csv', encoding = "ISO-8859-1")

# %%
data.head()  #Inspecting the first 5 rows
# Out:
#        budget                                 company country        director  \
# 0   8000000.0           Columbia Pictures Corporation     USA      Rob Reiner
# 1   6000000.0                      Paramount Pictures     USA     John Hughes
# 2  15000000.0                      Paramount Pictures     USA      Tony Scott
# 3  18500000.0  Twentieth Century Fox Film Corporation     USA   James Cameron
# 4   9000000.0                    Walt Disney Pictures     USA  Randal Kleiser
#
#        genre        gross                      name rating    released  \
# 0  Adventure   52287414.0               Stand by Me      R  1986-08-22
# 1     Comedy   70136369.0  Ferris Bueller's Day Off  PG-13  1986-06-11
# 2     Action  179800601.0                   Top Gun     PG  1986-05-16
# 3     Action   85160248.0                    Aliens      R  1986-07-18
# 4  Adventure   18564613.0   Flight of the Navigator     PG  1986-08-01
#
#    runtime  score               star   votes         writer  year
# ...

# %%
data.shape  #how many rows and columns i.e. dimensions
# Out:
# (6820, 15)

# %%
data.describe() #Summary Statistics
# Out:
#              budget         gross     runtime        score         votes  \
# count  6.820000e+03  6.820000e+03  6820.00000  6820.000000  6.820000e+03
# mean   2.458113e+07  3.349783e+07   106.55132     6.374897  7.121952e+04
# std    3.702254e+07  5.819760e+07    18.02818     1.003142  1.305176e+05
# min    0.000000e+00  7.000000e+01    50.00000     1.500000  2.700000e+01
# 25%    0.000000e+00  1.515839e+06    95.00000     5.800000  7.665250e+03
# 50%    1.100000e+07  1.213568e+07   102.00000     6.400000  2.589250e+04
# 75%    3.200000e+07  4.006534e+07   115.00000     7.100000  7.581225e+04
# max    3.000000e+08  9.366622e+08   366.00000     9.300000  1.861666e+06
#
#               year
# count  6820.000000
# mean   2001.000293
# std       8.944501
# min    1986.000000
# 25%    1993.000000
# 50%    2001.000000
# 75%    2009.000000
# max    2016.000000

# %% [markdown]
# There are 6 columns which are numerical. The central limit theorem has been applied to it and getting the mean, max, min, inter-quartile ranges

# %%
data.plot(kind='box', subplots=True, sharex=False, sharey=False, figsize=(16,5))
#plt.figure(figsize=(16,5))
pyplot.show()

# %%
data.hist()
# Out:
# array([[<AxesSubplot:title={'center':'budget'}>,
#         <AxesSubplot:title={'center':'gross'}>],
#        [<AxesSubplot:title={'center':'runtime'}>,
#         <AxesSubplot:title={'center':'score'}>],
#        [<AxesSubplot:title={'center':'votes'}>,
#         <AxesSubplot:title={'center':'year'}>]], dtype=object)

# %%
#Count the number of missing values in each column
data.isnull().sum()
# Out:
# budget      0
# company     0
# country     0
# director    0
# genre       0
# gross       0
# name        0
# rating      0
# released    0
# runtime     0
# score       0
# star        0
# votes       0
# writer      0
# year        0
# dtype: int64

# %% [markdown]
# Has no missing values

# %% [markdown]
# # Data Visualization

# %%
#grouping of this data on the basis of category
grp = data.groupby('genre')
x = grp['votes'].agg(np.mean)
y = grp['runtime'].agg(np.mean)
z = grp['budget'].agg(np.mean)
a = grp['score'].agg(np.mean)
b = grp['gross'].agg(np.mean)
print(x)
print(y)
print(z)
print(a)
print(b)

#An app with a name A, B, N, M -- that belongs to Art and Design so it is grouping the apps together, the game apps together 
#so its grouping the apps together and storing it in the variable grp

#Now from this grp variable, extracting the rating column and aggregating it with mean
#for eg if in art and design we have 13 apps -{4,3,4.3,5,...}<--mean of this ratings and storing it in my variable x
# Out:
# genre
# Action       112157.268971
# Adventure    106109.040816
# Animation    109753.974729
# Biography     70689.027855
# Comedy        44753.648558
# Crime         85038.632184
# Drama         53389.169668
# Family         6670.642857
# Fantasy       40032.812500
# Horror        55027.516245
# Musical        9914.500000
# Mystery      155121.315789
# Romance       19865.800000
# Sci-Fi       110283.307692
# Thriller       8990.333333
# War            4434.000000
# Western       18227.000000
# Name: votes, dtype: float64
# genre
# Action       109.000751
# Adventure    109.400510
# Animation     92.393502
# Biography    117.944290
# Comedy       101.210096
# Crime        111.118774
# Drama        111.921745
# Family        94.428571
# Fantasy       98.437500
# Horror        95.985560
# Musical      115.250000
# Mystery      107.789474
# Romance      100.933333
# Sci-Fi       102.769231
# Thriller      98.555556
# War          104.000000
# Western       97.500000
# ...

# %%
#the wrote the title which is Genre wise gross the x labelled to genre
plt.figure(figsize=(16,5)) # length to be 12 and height to be 5
plt.plot(x, 'ro', color='r')#by default the colour is red we could use blue, green
plt.xticks(rotation=90)# then showed the list of nos which I dont want so I did a plt .show
plt.title('Genre wise Votes')
plt.xlabel('Genre-->')
plt.ylabel('Votes-->')
plt.show()

# %%
#the wrote the title which is Genre wise gross the x labelled to genre
plt.figure(figsize=(16,5)) # length to be 12 and height to be 5
plt.plot(y, 'r--', color='b')#by default the colour is red we could use blue, green
plt.xticks(rotation=90)# then showed the list of nos which I dont want so I did a plt .show
plt.title('Genre wise Runtime')
plt.xlabel('Genre-->')
plt.ylabel('Runtime-->')
plt.show()

# %%
#the wrote the title which is Genre wise gross the x labelled to genre
plt.figure(figsize=(16,5)) # length to be 12 and height to be 5
plt.plot(z, 'bs', color='g')#by default the colour is red we could use blue, green
plt.xticks(rotation=90)# then showed the list of nos which I dont want so I did a plt .show
plt.title('Genre wise Budget')
plt.xlabel('Genre-->')
plt.ylabel('Budget-->')
plt.show()

# %%
#the wrote the title which is Genre wise gross the x labelled to genre
plt.figure(figsize=(16,5)) # length to be 12 and height to be 5
plt.plot(a, 'g^', color='r')#by default the colour is red we could use blue, green
plt.xticks(rotation=90)# then showed the list of nos which I dont want so I did a plt .show
plt.title('Genre wise Score')
plt.xlabel('Genre-->')
plt.ylabel('Score-->')
plt.show()

# %%
#the wrote the title which is Genre wise gross the x labelled to genre
plt.figure(figsize=(16,5)) # length to be 12 and height to be 5
plt.plot(b, 'r--', color='b')#by default the colour is red we could use blue, green
plt.xticks(rotation=90)# then showed the list of nos which I dont want so I did a plt .show
plt.title('Genre wise Gross')
plt.xlabel('Genre-->')
plt.ylabel('Gross-->')
plt.show()

# %%
#production budget and stars of the movie  Stars wise production budget
#grouping of this data on the basis of category
grp = data.groupby('star')
c = grp['budget'].agg(np.mean)
d = grp['budget'].agg(np.mean)
print(c)
# Out:
# star
# 'Weird Al' Yankovic    5.000000e+06
# 50 Cent                4.000000e+07
# A.J. Cook              2.600000e+07
# Aaliyah                3.500000e+07
# Aamir Khan             1.488342e+06
#                            ...
# Zoey Deutch            3.400000e+07
# Zooey Deschanel        5.000000e+06
# Álex Angulo            0.000000e+00
# Élodie Bouchez         0.000000e+00
# Émilie Dequenne        0.000000e+00
# Name: budget, Length: 2504, dtype: float64

# %%
#the wrote the title which is Genre wise gross the x labelled to genre
plt.figure(figsize=(16,5)) # length to be 12 and height to be 5
plt.plot(c, '--r', color='r')#by default the colour is red we could use blue, green
plt.xticks(rotation=90)# then showed the list of nos which I dont want so I did a plt .show
plt.title('Star wise Budget')
plt.xlabel('Star-->')
plt.ylabel('Budget-->')
plt.show()

# %%
#the wrote the title which is Genre wise gross the x labelled to genre
plt.figure(figsize=(20,5)) # length to be 12 and height to be 5
plt.plot(c, '--r', color='b')#by default the colour is red we could use blue, green
plt.xticks(rotation=90)# then showed the list of nos which I dont want so I did a plt .show
plt.title('Star wise Budget')
plt.xlabel('Star-->')
plt.ylabel('Budget-->')
plt.show()

# %%
fig, ax = plt.subplots(1, 3)
fig.suptitle("Budget Distribution", fontsize=20)
sns.distplot(data["budget"], ax=ax[0])
sns.boxplot(data["budget"], ax=ax[1])
sns.violinplot(data["budget"], ax=ax[2])
# Out:
# C:\Users\Sabrina1\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Sabrina1\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
#Checking the existence of zeros in rows

(data==0).sum(axis=0).to_excel("zeros_per_feature.xlsx")
(data==0).sum(axis=0)
# Out:
# budget      2182
# company        0
# country        0
# director       0
# genre          0
# gross          0
# name           0
# rating         0
# released       0
# runtime        0
# score          0
# star           0
# votes          0
# writer         0
# year           0
# dtype: int64

# %% [markdown]
# The budget is 0 in 2182 observations

# %%
#genre of the movie
fig, ax = plt.subplots(1, 2)
#plt.figure(figsize=(16,5))
data["genre"].value_counts().plot.bar(color="purple", ax=ax[0], figsize=(16,5))
data["genre"].value_counts().plot.pie(autopct='%1.1f%%',shadow=True,textprops={"fontsize": 10},ax=ax[1], figsize=(16,5))
fig.suptitle("Genre Frequency", fontsize=15)
plt.xticks(rotation=90)
plt.yticks(rotation=45)
# Out:
# (array([], dtype=float64), [])

# %%
fig, ax = plt.subplots(1, 3)
fig.suptitle("Gross Revenue Distribution", fontsize=15)
sns.distplot(data["gross"], ax=ax[0])
sns.boxplot(data["gross"], ax=ax[1])
sns.violinplot(data["gross"], ax=ax[2])
# Out:
# C:\Users\Sabrina1\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Sabrina1\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
fig, ax = plt.subplots(1, 3)
fig.suptitle("Score Distribution", fontsize=15)
sns.distplot(data["score"], ax=ax[0])
sns.boxplot(data["score"], ax=ax[1])
sns.violinplot(data["score"], ax=ax[2])
# Out:
# C:\Users\Sabrina1\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Sabrina1\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...
